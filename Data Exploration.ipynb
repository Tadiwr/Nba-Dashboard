# %%
import requests as req
from IPython.core.display import JSON
import json

url = "http://site.api.espn.com/apis/site/v2/sports/basketball/nba/teams/1"
data = req.get(url).text
data = json.loads(data)

# %%
 # type: ignore
import pandas as pd
i = data["team"]["record"]["items"][0]["stats"]
pd.DataFrame(i)
# Out:
#                   name        value
# 0             OTLosses     0.000000
# 1               OTWins     0.000000
# 2     avgPointsAgainst   116.745766
# 3         avgPointsFor   116.389830
# 4         differential    -0.300000
# 5   divisionWinPercent     0.500000
# 6          gamesBehind    13.000000
# 7          gamesPlayed    59.000000
# 8     leagueWinPercent     0.472222
# 9               losses    30.000000
# 10         playoffSeed     8.000000
# 11              points    -0.500000
# 12       pointsAgainst  6888.000000
# 13           pointsFor  6867.000000
# 14              streak    -2.000000
# 15                ties     0.000000
# 16          winPercent     0.491525
# 17                wins    29.000000

# %%
from data.repo import Repo

team = 23
x = Repo.teams.getTeamData(id=team)

# %%
from utils.visuals import *

SummarizeAllTeamsWinPercentage()
