# %%
import requests as req
import json
import pandas as pd
from data.models.team_model import TeamModel 

id = 5

url = "http://site.api.espn.com/apis/site/v2/sports/basketball/nba/teams/"
team_json = req.get(url + str(id)).text
team_dict = json.loads(team_json)
team_dict = team_dict["team"]
team_model = TeamModel(team_dict)
team_model

# %%
stats = team_dict["record"]["items"][0]["stats"]

# %% [markdown]
# Win Percentage

# %%
stats

# %%
pd.DataFrame(stats)

# %%
team_model.stats.wins

# %%
from data.repo import Repo as rp

rp.static.get_win_percentages()
# Out:
#     Unnamed: 0                    Team  Win Percentage
# 0            0           Atlanta Hawks       50.000000
# 1            1          Boston Celtics       68.831170
# 2            2    New Orleans Pelicans       50.649350
# 3            3           Chicago Bulls       47.368422
# 4            4     Cleveland Cavaliers       62.337660
# 5            5        Dallas Mavericks       48.051947
# 6            6          Denver Nuggets       67.105263
# 7            7         Detroit Pistons       21.052632
# 8            8   Golden State Warriors       51.948050
# 9            9         Houston Rockets       23.376623
# 10          10          Indiana Pacers       42.857143
# 11          11             LA Clippers       53.246754
# 12          12      Los Angeles Lakers       50.000000
# 13          13              Miami Heat       51.948050
# 14          14         Milwaukee Bucks       71.428573
# 15          15  Minnesota Timberwolves       50.649350
# 16          16           Brooklyn Nets       53.947370
# 17          17         New York Knicks       57.142860
# 18          18           Orlando Magic       42.105263
# 19          19      Philadelphia 76ers       65.789473
# 20          20            Phoenix Suns       53.947370
# 21          21  Portland Trail Blazers       42.105263
# 22          22        Sacramento Kings       60.526320
# 23          23       San Antonio Spurs       25.000000
# 24          24   Oklahoma City Thunder       49.350650
# 25          25               Utah Jazz       47.368422
# 26          26      Washington Wizards       44.736840
# 27          27         Toronto Raptors       50.000000
# 28          28       Memphis Grizzlies       63.157890
# 29          29       Charlotte Hornets       33.766234
