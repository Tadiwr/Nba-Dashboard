# %%
import requests as req
from IPython.core.display import JSON
import json
import pandas as pd

url = "http://site.api.espn.com/apis/site/v2/sports/basketball/nba/scoreboard"
data = req.get(url).text
data = json.loads(data)

data
# Out:
# {'leagues': [{'id': '46',
#    'uid': 's:40~l:46',
#    'name': 'National Basketball Association',
#    'abbreviation': 'NBA',
#    'slug': 'nba',
#    'season': {'year': 2023,
#     'startDate': '2022-08-30T07:00Z',
#     'endDate': '2023-06-24T06:59Z',
#     'type': {'id': '2',
#      'type': 2,
#      'name': 'Regular Season',
#      'abbreviation': 'reg'}},
#    'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/leagues/500/nba.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'default'],
#      'lastUpdated': '2018-06-05T12:07Z'},
#     {'href': 'https://a.espncdn.com/i/teamlogos/leagues/500-dark/nba.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'dark'],
#      'lastUpdated': '2018-06-05T12:07Z'}],
#    'calendarType': 'day',
#    'calendarIsWhitelist': True,
#    'calendarStartDate': '2022-08-30T07:00Z',
#    'calendarEndDate': '2023-06-24T06:59Z',
#    'calendar': ['2022-09-30T07:00Z',
# ...

# %% [markdown]
# Getting all the games live/upcoming

# %%
events = data["events"]
events
# Out:
# [{'id': '401469291',
#   'uid': 's:40~l:46~e:401469291',
#   'date': '2023-03-29T23:00Z',
#   'name': 'Milwaukee Bucks at Indiana Pacers',
#   'shortName': 'MIL @ IND',
#   'season': {'year': 2023, 'type': 2, 'slug': 'regular-season'},
#   'competitions': [{'id': '401469291',
#     'uid': 's:40~l:46~e:401469291~c:401469291',
#     'date': '2023-03-29T23:00Z',
#     'attendance': 16524,
#     'type': {'id': '1', 'abbreviation': 'STD'},
#     'timeValid': True,
#     'neutralSite': False,
#     'conferenceCompetition': False,
#     'recent': False,
#     'venue': {'id': '2183',
#      'fullName': 'Gainbridge Fieldhouse',
#      'address': {'city': 'Indianapolis', 'state': 'IN'},
#      'capacity': 17923,
#      'indoor': True},
#     'competitors': [{'id': '11',
#       'uid': 's:40~l:46~t:11',
#       'type': 'team',
#       'order': 0,
#       'homeAway': 'home',
#       'winner': False,
#       'team': {'id': '11',
#        'uid': 's:40~l:46~t:11',
#        'location': 'Indiana',
# ...

# %% [markdown]
# A single game short name

# %%
game = events[0]
game["uid"]
# Out:
# 's:40~l:46~e:401469291'

# %% [markdown]
# Getting the Date

# %%
date = game["date"]
date.split("T")[1]
# Out:
# '23:00Z'

# %% [markdown]
# Getting displaying the whole scoreboard

# %%
game["status"]
# Out:
# {'clock': 0.0,
#  'displayClock': '0.0',
#  'period': 0,
#  'type': {'id': '1',
#   'name': 'STATUS_SCHEDULED',
#   'state': 'pre',
#   'completed': False,
#   'description': 'Scheduled',
#   'detail': 'Wed, March 29th at 7:00 PM EDT',
#   'shortDetail': '3/29 - 7:00 PM EDT'}}

# %%
url = "http://site.api.espn.com/apis/site/v2/sports/basketball/nba/scoreboard"
data = req.get(url).text
data = json.loads(data)

events = data["events"]

shortNames = []
dates = []
times = []
for event in events:
    game = event["shortName"]
    game_date = event["date"].split("T")[0]
    game_time = event["date"].split("T")[1]
    times.append(game_time)
    dates.append(game_date)
    shortNames.append(game)

scoreboard = pd.DataFrame({
    "Games":shortNames,
    "Date": dates,
    "Time":times
})

scoreboard
# Out:
#        Games        Date    Time
# 0  MIL @ IND  2023-03-29  23:00Z
# 1  HOU @ BKN  2023-03-29  23:30Z
# 2   MIA @ NY  2023-03-29  23:30Z
# 3  DAL @ PHI  2023-03-29  23:30Z
# 4  LAL @ CHI  2023-03-30  00:00Z
# 5  LAC @ MEM  2023-03-30  00:00Z
# 6  DET @ OKC  2023-03-30  00:00Z
# 7  UTAH @ SA  2023-03-30  00:00Z
# 8  MIN @ PHX  2023-03-30  02:00Z
# 9  SAC @ POR  2023-03-30  02:00Z

# %% [markdown]
# Results

# %%
from data.repo import Repo

Repo.scoreboard
# Out:
#        Games        Date    Time
# 0  MIL @ IND  2023-03-29  23:00Z
# 1  HOU @ BKN  2023-03-29  23:30Z
# 2   MIA @ NY  2023-03-29  23:30Z
# 3  DAL @ PHI  2023-03-29  23:30Z
# 4  LAL @ CHI  2023-03-30  00:00Z
# 5  LAC @ MEM  2023-03-30  00:00Z
# 6  DET @ OKC  2023-03-30  00:00Z
# 7  UTAH @ SA  2023-03-30  00:00Z
# 8  SAC @ POR  2023-03-30  02:00Z
# 9  MIN @ PHX  2023-03-30  02:15Z
